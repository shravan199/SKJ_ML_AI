# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#### 1. Age- Age of patient at time of operation (numerical)
#### 2. Year - Patient's year of operation (year - 1900, numerical)
#### 3. Num_Aux_Nodes- Number of positive axillary nodes detected (numerical)
#### 4. Survival status (class attribute)
    ##### 1 = the patient survived 5 years or longer
    ##### 2 = the patient died within 5 year

# %%
haberman = pd.read_csv('./data/haberman.csv', names= ['age', 'year_operation', 'num_aux_nodes',  'survival_status'])
haberman
# Out:
#      age  year_operation  num_aux_nodes  survival_status
# 0     30              64              1                1
# 1     30              62              3                1
# 2     30              65              0                1
# 3     31              59              2                1
# 4     31              65              4                1
# ..   ...             ...            ...              ...
# 301   75              62              1                1
# 302   76              67              0                1
# 303   77              65              3                1
# 304   78              65              1                2
# 305   83              58              2                2
#
# [306 rows x 4 columns]

# %%
haberman.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              306 non-null    int64
#  1   year_operation   306 non-null    int64
#  2   num_aux_nodes    306 non-null    int64
#  3   survival_status  306 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
haberman['survival_status'].value_counts()
# Out:
# 1    225
# 2     81
# Name: survival_status, dtype: int64

# %% [markdown]
# #### 2-D scatter plot

# %%
plt.close()
sns.scatterplot(x='age', y='num_aux_nodes', hue='survival_status', data=haberman, )
plt.show()

# %%
plt.figure(figsize=(15, 6))

sns.set_style(style='whitegrid')
sns.FacetGrid(data=haberman, hue='survival_status', size=5) \
   .map(plt.scatter, 'age', 'num_aux_nodes') \
   .add_legend()

plt.show()
# Out:
# D:\Softwares\Anaconda\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Uni-variate analysis

# %%
sns.distplot(a=haberman['age'])
plt.show()
# Out:
# D:\Softwares\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(a=haberman['age'])
plt.show()
# Out:
# D:\Softwares\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(data=haberman, hue='survival_status', size=5, height=4 ) \
   .map(sns.distplot, 'age') \
   .add_legend()
plt.show()
# Out:
# D:\Softwares\Anaconda\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# D:\Softwares\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Softwares\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.bar

# %%
_bins= [year for year in np.arange(1958, 1970, 1)]
_bins
# Out:
# [1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969]

# %%
sns.FacetGrid(data=haberman, hue='survival_status', aspect=1.5, height=4, legend_out=False,) \
   .map(sns.distplot, 'year_operation') \
   .add_legend()

plt.show()
# Out:
# D:\Softwares\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Softwares\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(data=haberman, hue='survival_status', aspect=1.5, height=5, legend_out=False,) \
   .map(sns.distplot, 'num_aux_nodes') \
   .add_legend()

plt.show()
# Out:
# D:\Softwares\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Softwares\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.close()
sns.set_style(style='whitegrid')
sns.pairplot(data=haberman, hue='survival_status', height=2)
plt.show()

# %%
# PDF (Prob. Density funciton) and CDF (Cumulative Distribution function)

# %%
# plot cdf and pdf
counts, bin_edges = np.histogram(haberman['age'], bins= 10, density=True)


# compute pdf
pdf = counts/sum(counts)
print(pdf)
print(bin_edges)

# compute cdf
cdf = np.cumsum(pdf)

plt.plot(bin_edges[1: ], cdf)
plt.plot(bin_edges[1: ], pdf)
# Out:
# [0.05228758 0.08823529 0.1503268  0.17320261 0.17973856 0.13398693
#  0.13398693 0.05882353 0.02287582 0.00653595]
# [30.  35.3 40.6 45.9 51.2 56.5 61.8 67.1 72.4 77.7 83. ]

# %%
haberman['age'].describe()
# Out:
# count    306.000000
# mean      52.457516
# std       10.803452
# min       30.000000
# 25%       44.000000
# 50%       52.000000
# 75%       60.750000
# max       83.000000
# Name: age, dtype: float64

# %%
haberman.columns
# Out:
# Index(['age', 'year_operation', 'num_aux_nodes', 'survival_status'], dtype='object')

# %%
# plot cdf and pdf
counts, bin_edges = np.histogram(haberman['year_operation'], bins= 10, density=True)


# compute pdf
pdf = counts/sum(counts)
print(pdf)
print(bin_edges)

# compute cdf
cdf = np.cumsum(pdf)

plt.plot(bin_edges[1: ], cdf)
plt.plot(bin_edges[1: ], pdf)
# Out:
# [0.20588235 0.09150327 0.08496732 0.0751634  0.09803922 0.10130719
#  0.09150327 0.09150327 0.08169935 0.07843137]
# [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]

# %%
haberman['year_operation'].describe()
# Out:
# count    306.000000
# mean      62.852941
# std        3.249405
# min       58.000000
# 25%       60.000000
# 50%       63.000000
# 75%       65.750000
# max       69.000000
# Name: year_operation, dtype: float64
