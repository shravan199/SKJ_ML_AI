# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nas = pd.read_csv('./data/nas.csv')
nas.head()
# Out:
#          STUID        State  District Gender       Age  Category  \
# 0  26011001001  Maharashtra         1   Girl  13 years       3.0
# 1  26011001002  Maharashtra         1   Girl  15 years       3.0
# 2  26011001003  Maharashtra         1   Girl  14 years       3.0
# 3  26011001004  Maharashtra         1    Boy  13 years       3.0
# 4  26011001005  Maharashtra         1   Girl  14 years       3.0
#
#    Same.language    Siblings Handicap      Father.edu  ...  \
# 0            2.0   1 sibling       No      Illiterate  ...
# 1            2.0  3 siblings       No             NaN  ...
# 2            2.0  3 siblings       No  Degree & above  ...
# 3            2.0  3 siblings       No       Secondary  ...
# 4            2.0  2 siblings       No         Primary  ...
#
#   Express.science.views     Watch.TV Read.magazine   Read.a.book   Play.games  \
# 0                 Agree    Every day         Never  Once a month  Once a week
# ...

# %%
nas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8801 entries, 0 to 8800
# Data columns (total 64 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STUID                   8801 non-null   int64
#  1   State                   8801 non-null   object
#  2   District                8801 non-null   int64
#  3   Gender                  8799 non-null   object
#  4   Age                     8569 non-null   object
#  5   Category                8232 non-null   float64
#  6   Same.language           8572 non-null   float64
#  7   Siblings                8801 non-null   object
#  8   Handicap                8304 non-null   object
#  9   Father.edu              8147 non-null   object
#  10  Mother.edu              7950 non-null   object
#  11  Father.occupation       7761 non-null   object
#  12  Mother.occupation       6626 non-null   object
#  13  Below.poverty           7347 non-null   object
# ...

# %%
nas.isnull().sum()
# Out:
# STUID                   0
# State                   0
# District                0
# Gender                  2
# Age                   232
#                      ...
# Help.in.household      44
# Maths..              4611
# Reading..            4574
# Science..            4657
# Social..             4682
# Length: 64, dtype: int64

# %%
nas[['Maths..', 'Reading..', 'Science..', 'Social..']].describe()
# Out:
#            Maths..    Reading..    Science..     Social..
# count  4190.000000  4227.000000  4144.000000  4119.000000
# mean     31.601532    55.404436    36.313272    40.502527
# std      14.734404    23.279043    13.199105    14.479584
# min       0.000000     0.000000     0.000000     0.000000
# 25%      22.030000    35.575000    27.270000    30.610000
# 50%      28.070000    56.670000    34.550000    38.780000
# 75%      36.840000    73.330000    43.640000    51.020000
# max      94.740000   100.000000    85.450000    89.800000

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 4, 1)
sns.boxplot(y='Maths..', data=nas)

plt.subplot(1, 4, 2)
sns.boxplot(y='Reading..', data=nas)

plt.subplot(1, 4, 3)
sns.boxplot(y='Science..', data=nas)

plt.subplot(1, 4, 4)
sns.boxplot(y='Social..', data=nas)

plt.show()

# %%
plt.figure(figsize=(15, 5))

_bins = [num for num in np.arange(0, 101, 2)]
sns.histplot(nas['Maths..'], bins=_bins)
plt.show()

# %%
plt.figure(figsize=(15, 5))

sns.scatterplot(nas['Maths..'])
plt.show()
# Out:
# D:\Softwares\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
nas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8801 entries, 0 to 8800
# Data columns (total 64 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STUID                   8801 non-null   int64
#  1   State                   8801 non-null   object
#  2   District                8801 non-null   int64
#  3   Gender                  8799 non-null   object
#  4   Age                     8569 non-null   object
#  5   Category                8232 non-null   float64
#  6   Same.language           8572 non-null   float64
#  7   Siblings                8801 non-null   object
#  8   Handicap                8304 non-null   object
#  9   Father.edu              8147 non-null   object
#  10  Mother.edu              7950 non-null   object
#  11  Father.occupation       7761 non-null   object
#  12  Mother.occupation       6626 non-null   object
#  13  Below.poverty           7347 non-null   object
# ...

# %%
nas.iloc[ 2774: 2778, :]
# Out:
#             STUID        State  District Gender       Age  Category  \
# 2774  26071093037  Maharashtra         7   Girl  14 years       NaN
# 2775  26071093038  Maharashtra         7   Girl  14 years       NaN
# 2776  26071093039  Maharashtra         7   Girl  14 years       NaN
# 2777  26071093040  Maharashtra         7   Girl  14 years       NaN
#
#       Same.language      Siblings Handicap    Father.edu  ...  \
# 2774            1.0  Single child       No     Secondary  ...
# 2775            1.0  Single child       No     Secondary  ...
# 2776            1.0  Single child       No  Sr secondary  ...
# 2777            1.0  Single child       No     Secondary  ...
#
#      Express.science.views   Watch.TV Read.magazine  Read.a.book Play.games  \
# 2774                 Agree  Every day  Once a month  Once a week  Every day
# 2775                 Agree  Every day  Once a month  Once a week  Every day
# 2776                 Agree  Every day  Once a month  Once a week  Every day
# ...

# %%
nas['Num_of_Siblings_test'] = nas['Siblings'].str[:2]

# %%
sns.boxplot(y='Siblings', x='Mother.edu', data=nas)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3416\999158929.py in <module>
# ----> 1 sns.boxplot(y='Siblings', x='Mother.edu', data=nas)
#       2 plt.show()
#
# D:\Softwares\Anaconda\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\Softwares\Anaconda\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2241 ):
#    2242
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2244                           orient, color, palette, saturation,
# ...

# %%
nas['Siblings'] = nas['Siblings'].apply(lambda value:'0 sibling' if value == 'Single child' else value)

# %%
nas.drop(labels='Siblings_2', axis=1, inplace=True)
nas
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3416\3653214730.py in <module>
# ----> 1 nas.drop(labels='Siblings_2', axis=1, inplace=True)
#       2 nas
#
# D:\Softwares\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# D:\Softwares\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
nas.drop(labels='Num_of_Siblings_test', axis=1, inplace=True)
nas
# Out:
#             STUID        State  District Gender       Age  Category  \
# 0     26011001001  Maharashtra         1   Girl  13 years       3.0
# 1     26011001002  Maharashtra         1   Girl  15 years       3.0
# 2     26011001003  Maharashtra         1   Girl  14 years       3.0
# 3     26011001004  Maharashtra         1    Boy  13 years       3.0
# 4     26011001005  Maharashtra         1   Girl  14 years       3.0
# ...           ...          ...       ...    ...       ...       ...
# 8796  26141270036  Maharashtra        14    Boy  13 years       4.0
# 8797  26141270037  Maharashtra        14    Boy  13 years       3.0
# 8798  26141270038  Maharashtra        14    Boy  14 years       4.0
# 8799  26141270039  Maharashtra        14    Boy  13 years       4.0
# 8800  26141270040  Maharashtra        14    Boy  13 years       4.0
#
#       Same.language    Siblings Handicap      Father.edu  ...  \
# 0               2.0   1 sibling       No      Illiterate  ...
# ...

# %%
nas['Num_of_Siblings'] = nas['Siblings'].str[:2].str.strip(' ')

# %%
nas['Num_of_Siblings']
# Out:
# 0       1
# 1       3
# 2       3
# 3       3
# 4       2
#        ..
# 8796    1
# 8797    2
# 8798    1
# 8799    1
# 8800    1
# Name: Num_of_Siblings, Length: 8801, dtype: object

# %%
nas.pivot_table(index=['Mother.edu'], columns=['Num_of_Siblings'])
# Out:
#                  Category                                           District  \
# Num_of_Siblings         0         1         2         3        4+          0
# Mother.edu
# Degree & above   3.684211  3.082353  2.428571  2.909091  2.166667  10.300000
# Illiterate       2.560000  2.787449  2.732329  2.700599  2.560920   7.477273
# Primary          2.623529  2.952381  2.757823  2.659847  2.561702   7.250000
# Secondary        2.916667  3.010891  2.857849  2.786145  2.836820   7.945652
# Sr secondary     3.304348  2.958974  2.674797  2.446809  2.681818   8.625000
#
#                                                          ...  Science..  \
# Num_of_Siblings         1         2         3        4+  ...          0
# Mother.edu                                               ...
# Degree & above   8.693182  7.555556  8.000000  7.666667  ...  54.025714
# Illiterate       8.399625  8.523294  7.404135  7.880597  ...  31.169184
# ...

# %%
nas['Num_of_Siblings'].astype('int32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3416\4157762215.py in <module>
# ----> 1 nas['Num_of_Siblings'].astype('int32')
#
# D:\Softwares\Anaconda\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# D:\Softwares\Anaconda\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...

# %%
nas[nas['Siblings'].str.contains('4+')]
# Out:
#             STUID        State  District Gender        Age  Category  \
# 7     26011001013  Maharashtra         1   Girl        NaN       1.0
# 9     26011001015  Maharashtra         1   Girl   13 years       4.0
# 11    26011001018  Maharashtra         1   Girl   13 years       3.0
# 17    26011001025  Maharashtra         1    Boy   15 years       4.0
# 52    26011002033  Maharashtra         1   Girl   14 years       2.0
# ...           ...          ...       ...    ...        ...       ...
# 8713  26141268030  Maharashtra        14    Boy   14 years       4.0
# 8727  26141269004  Maharashtra        14    Boy  16+ years       3.0
# 8730  26141269007  Maharashtra        14   Girl   13 years       3.0
# 8735  26141269013  Maharashtra        14    Boy  16+ years       4.0
# 8740  26141269018  Maharashtra        14    Boy   14 years       4.0
#
#       Same.language     Siblings Handicap      Father.edu  ...   Watch.TV  \
# ...

# %%
nas['Siblings'].value_counts(sort=True)
# Out:
# 2 siblings     2979
# 1 sibling      2726
# 3 siblings     1526
# 4+ siblings    1167
# 0 sibling       403
# Name: Siblings, dtype: int64

# %%
plt.figure(figsize=(21, 6))
plt.subplot(1, 3, 1)
sns.histplot(x='Siblings', data=nas)

plt.subplot(1, 3, 2)
sns.histplot(x='Mother.edu',hue='Siblings', data=nas)

plt.subplot(1, 3, 3)
sns.histplot(x='Siblings', data=nas, hue='Mother.edu')
plt.show()

# %%
plt.figure(figsize=(18, 5))

sns.heatmap(data=nas[['Siblings', 'Mother.edu']])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3416\1570349798.py in <module>
#       1 plt.figure(figsize=(18, 5))
#       2
# ----> 3 sns.heatmap(data=nas[['Siblings', 'Mother.edu']])
#       4 plt.show()
#
# D:\Softwares\Anaconda\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\Softwares\Anaconda\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     538     """
#     539     # Initialize the plotter object
# ...

# %%
sns.boxplot(x='Num_of_Siblings', y='Mother.edu', data=nas)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3416\7611559.py in <module>
# ----> 1 sns.boxplot(x='Num_of_Siblings', data=nas)
#       2 plt.show()
#
# D:\Softwares\Anaconda\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\Softwares\Anaconda\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2241 ):
#    2242
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2244                           orient, color, palette, saturation,
# ...

# %%
nas.pivot_table(index='Father.edu', columns='Age', values='Science..', aggfunc=np.mean)
# Out:
# Age             11- years   12 years   13 years   14 years   15 years  \
# Father.edu
# Degree & above        NaN  46.752857  44.805143  42.676944  29.090000
# Illiterate            NaN  29.870000  33.758968  35.319478  33.413333
# Primary         48.486667  34.121667  37.617555  36.700267  35.162768
# Secondary       29.696667  33.593810  38.164402  36.738859  32.872800
# Sr secondary          NaN  40.113750  39.046503  39.050278  38.615714
#
# Age             16+ years
# Father.edu
# Degree & above  32.730000
# Illiterate      33.116786
# Primary         32.364000
# Secondary       30.960000
# Sr secondary    31.513333

# %%
plt.figure(figsize=(20, 7))
sns.boxplot(y='Science..', x='Father.edu', hue='Age', data=nas)
plt.show()
