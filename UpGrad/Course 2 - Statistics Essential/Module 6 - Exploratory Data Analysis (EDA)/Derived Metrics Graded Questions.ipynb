# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
grades = pd.read_csv('./data/grades.csv')

# %%
grades.head(10)
# Out:
#                                                                           submission  \
# 0  https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44aa-88d3-6b36aaa69b02/DDA1610095.zip
# 1  https://ckd.upgrad.com/UpGrad/185242ff-7508-4cc4-afa3-5865733ba1d4/DDA1610288.zip
# 2  https://ckd.upgrad.com/UpGrad/a353d129-c100-4342-aa95-a7018ff93150/DDA1610106.zip
# 3  https://ckd.upgrad.com/UpGrad/002fc912-faa1-4948-9358-fcdabfd7669c/DDA1610261.zip
# 4  https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4ffa-9bf1-06bdb1a7cf8f/DDA1610028.zip
# 5  https://ckd.upgrad.com/UpGrad/0ab308ab-2b3a-4c74-9bac-c12567a04754/DDA1610059.zip
# 6  https://ckd.upgrad.com/UpGrad/ba2c249c-dac8-4619-a978-7fc4d15a9a89/DDA1610087.zip
# 7  https://ckd.upgrad.com/UpGrad/d8969806-6760-4428-a861-545fb4aff136/DDA1610042.zip
# 8  https://ckd.upgrad.com/UpGrad/5ff1d0ab-816b-48c0-a5a2-b76b1fd1d787/DDA1610060.zip
# 9    https://ckd.upgrad.com/UpGrad/0d507851-d102-4714-866c-348b0acf053f/DDA1610195.R
#
#          submit_time
# ...

# %%
grades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   submission   198 non-null    object
#  1   submit_time  198 non-null    object
# dtypes: object(2)
# memory usage: 3.2+ KB

# %%
grades['submit_time']
# Out:
# 0      01/03/17-20:28:52
# 1      01/03/17-20:18:21
# 2      01/03/17-22:37:08
# 3      01/02/17-21:43:19
# 4      01/03/17-15:27:49
#              ...
# 193    01/03/17-22:43:12
# 194    01/09/17-23:59:34
# 195    12/19/16-21:44:13
# 196    01/09/17-23:23:06
# 197    01/03/17-22:32:38
# Name: submit_time, Length: 198, dtype: object

# %%
grades['submit_time'] = pd.to_datetime(grades['submit_time'], format='%m/%d/%y-%H:%M:%S')

# %%
grades['submit_time'].head(10)
# Out:
# 0   2017-01-03 20:28:52
# 1   2017-01-03 20:18:21
# 2   2017-01-03 22:37:08
# 3   2017-01-02 21:43:19
# 4   2017-01-03 15:27:49
# 5   2017-01-04 02:43:46
# 6   2017-01-03 23:41:25
# 7   2017-01-09 23:49:09
# 8   2016-12-30 14:14:17
# 9   2017-01-03 21:18:04
# Name: submit_time, dtype: datetime64[ns]

# %%
grades['day'] = grades['submit_time'].dt.day
grades['day']
# Out:
# 0       3
# 1       3
# 2       3
# 3       2
# 4       3
#        ..
# 193     3
# 194     9
# 195    19
# 196     9
# 197     3
# Name: day, Length: 198, dtype: int64

# %%
grades['month'] = grades['submit_time'].dt.month
grades['month']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 193     1
# 194     1
# 195    12
# 196     1
# 197     1
# Name: month, Length: 198, dtype: int64

# %%
grades['year'] = grades['submit_time'].dt.year
grades['year']
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 193    2017
# 194    2017
# 195    2016
# 196    2017
# 197    2017
# Name: year, Length: 198, dtype: int64

# %%
grades['hour'] = grades['submit_time'].dt.hour
grades['hour']
# Out:
# 0      20
# 1      20
# 2      22
# 3      21
# 4      15
#        ..
# 193    22
# 194    23
# 195    21
# 196    23
# 197    22
# Name: hour, Length: 198, dtype: int64

# %%
grades['minute'] = grades['submit_time'].dt.minute
grades['minute']
# Out:
# 0      28
# 1      18
# 2      37
# 3      43
# 4      27
#        ..
# 193    43
# 194    59
# 195    44
# 196    23
# 197    32
# Name: minute, Length: 198, dtype: int64

# %%
grades['second'] = grades['submit_time'].dt.second
grades['second']
# Out:
# 0      52
# 1      21
# 2       8
# 3      19
# 4      49
#        ..
# 193    12
# 194    34
# 195    13
# 196     6
# 197    38
# Name: second, Length: 198, dtype: int64

# %%
grades.head(60)
# Out:
#                                                                               submission  \
# 0      https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44aa-88d3-6b36aaa69b02/DDA1610095.zip
# 1      https://ckd.upgrad.com/UpGrad/185242ff-7508-4cc4-afa3-5865733ba1d4/DDA1610288.zip
# 2      https://ckd.upgrad.com/UpGrad/a353d129-c100-4342-aa95-a7018ff93150/DDA1610106.zip
# 3      https://ckd.upgrad.com/UpGrad/002fc912-faa1-4948-9358-fcdabfd7669c/DDA1610261.zip
# 4      https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4ffa-9bf1-06bdb1a7cf8f/DDA1610028.zip
# 5      https://ckd.upgrad.com/UpGrad/0ab308ab-2b3a-4c74-9bac-c12567a04754/DDA1610059.zip
# 6      https://ckd.upgrad.com/UpGrad/ba2c249c-dac8-4619-a978-7fc4d15a9a89/DDA1610087.zip
# 7      https://ckd.upgrad.com/UpGrad/d8969806-6760-4428-a861-545fb4aff136/DDA1610042.zip
# 8      https://ckd.upgrad.com/UpGrad/5ff1d0ab-816b-48c0-a5a2-b76b1fd1d787/DDA1610060.zip
# ...

# %%
grades['is_zip_file_extension'] = grades['submission'].str.contains(".zip")

# %%
grades['is_zip_file_extension'].sum()
# Out:
# 189

# %%
grades['is_R_file_extension'] = grades['submission'].str.contains(".R")

# %%
grades['is_R_file_extension'].sum()
# Out:
# 7

# %%
pd.options.display.max_colwidth =100

# %%
grades['submission']
# Out:
# 0      https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44aa-88d3-6b36aaa69b02/DDA1610095.zip
# 1      https://ckd.upgrad.com/UpGrad/185242ff-7508-4cc4-afa3-5865733ba1d4/DDA1610288.zip
# 2      https://ckd.upgrad.com/UpGrad/a353d129-c100-4342-aa95-a7018ff93150/DDA1610106.zip
# 3      https://ckd.upgrad.com/UpGrad/002fc912-faa1-4948-9358-fcdabfd7669c/DDA1610261.zip
# 4      https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4ffa-9bf1-06bdb1a7cf8f/DDA1610028.zip
#                                              ...
# 193    https://ckd.upgrad.com/UpGrad/ba485323-bba6-4b16-9283-958406a78a6f/DDA1610228.zip
# 194    https://ckd.upgrad.com/UpGrad/a65694d0-339b-44f3-b6bf-a3b15c87ab9c/DDA1610200.zip
# 195    https://ckd.upgrad.com/UpGrad/c3876ddf-2b2f-4a55-952d-2df78fc12ad8/DDA1610183.zip
# 196      https://ckd.upgrad.com/UpGrad/2b9732ad-0985-4af4-a473-4700174afbc0/DDA1610013.R
# 197    https://ckd.upgrad.com/UpGrad/21da378c-75a4-4a37-9924-d2a971ba5290/DDA1610048.zip
# ...

# %%
type(grades['submission'])
# Out:
# pandas.core.series.Series

# %%
get_index_of_dot = grades['submission'].str.rfind('.')

# %%
get_index_of_dot
# Out:
# 0      77
# 1      77
# 2      77
# 3      77
# 4      77
#        ..
# 193    77
# 194    77
# 195    77
# 196    77
# 197    77
# Name: submission, Length: 198, dtype: int64

# %%
grades['file_extension'] = grades['submission'].str[get_index_of_dot+1 :]

# %%
grades['file_extension']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 193   NaN
# 194   NaN
# 195   NaN
# 196   NaN
# 197   NaN
# Name: file_extension, Length: 198, dtype: float64

# %%
grades['file_extension']= grades['submission'].str.rsplit('.').str[-1]

# %%
grades['file_extension'].value_counts()
# Out:
# zip    189
# R        7
# 7z       2
# Name: file_extension, dtype: int64

# %%
type(grades['file_extension'])
# Out:
# pandas.core.series.Series

# %%
grades
# Out:
#                                                                             submission  \
# 0    https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44aa-88d3-6b36aaa69b02/DDA1610095.zip
# 1    https://ckd.upgrad.com/UpGrad/185242ff-7508-4cc4-afa3-5865733ba1d4/DDA1610288.zip
# 2    https://ckd.upgrad.com/UpGrad/a353d129-c100-4342-aa95-a7018ff93150/DDA1610106.zip
# 3    https://ckd.upgrad.com/UpGrad/002fc912-faa1-4948-9358-fcdabfd7669c/DDA1610261.zip
# 4    https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4ffa-9bf1-06bdb1a7cf8f/DDA1610028.zip
# ..                                                                                 ...
# 193  https://ckd.upgrad.com/UpGrad/ba485323-bba6-4b16-9283-958406a78a6f/DDA1610228.zip
# 194  https://ckd.upgrad.com/UpGrad/a65694d0-339b-44f3-b6bf-a3b15c87ab9c/DDA1610200.zip
# 195  https://ckd.upgrad.com/UpGrad/c3876ddf-2b2f-4a55-952d-2df78fc12ad8/DDA1610183.zip
# 196    https://ckd.upgrad.com/UpGrad/2b9732ad-0985-4af4-a473-4700174afbc0/DDA1610013.R
# ...

# %%
grades.drop(columns=['is_zip_file_extension', 'is_R_file_extension'], inplace=True)

# %%
grades
# Out:
#                                                                             submission  \
# 0    https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44aa-88d3-6b36aaa69b02/DDA1610095.zip
# 1    https://ckd.upgrad.com/UpGrad/185242ff-7508-4cc4-afa3-5865733ba1d4/DDA1610288.zip
# 2    https://ckd.upgrad.com/UpGrad/a353d129-c100-4342-aa95-a7018ff93150/DDA1610106.zip
# 3    https://ckd.upgrad.com/UpGrad/002fc912-faa1-4948-9358-fcdabfd7669c/DDA1610261.zip
# 4    https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4ffa-9bf1-06bdb1a7cf8f/DDA1610028.zip
# ..                                                                                 ...
# 193  https://ckd.upgrad.com/UpGrad/ba485323-bba6-4b16-9283-958406a78a6f/DDA1610228.zip
# 194  https://ckd.upgrad.com/UpGrad/a65694d0-339b-44f3-b6bf-a3b15c87ab9c/DDA1610200.zip
# 195  https://ckd.upgrad.com/UpGrad/c3876ddf-2b2f-4a55-952d-2df78fc12ad8/DDA1610183.zip
# 196    https://ckd.upgrad.com/UpGrad/2b9732ad-0985-4af4-a473-4700174afbc0/DDA1610013.R
# ...

# %%
grades.shape[0]
# Out:
# 198

# %%
file_extn_counts = grades['file_extension'].value_counts()
file_extn_counts
# Out:
# zip    189
# R        7
# 7z       2
# Name: file_extension, dtype: int64

# %%
file_extn_counts['zip']
# Out:
# 189

# %%
zip_percentage = (file_extn_counts['zip'] / grades.shape[0])*100
round(zip_percentage,2)
# Out:
# 95.45

# %%
grades.head(3)
# Out:
#                                                                           submission  \
# 0  https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44aa-88d3-6b36aaa69b02/DDA1610095.zip
# 1  https://ckd.upgrad.com/UpGrad/185242ff-7508-4cc4-afa3-5865733ba1d4/DDA1610288.zip
# 2  https://ckd.upgrad.com/UpGrad/a353d129-c100-4342-aa95-a7018ff93150/DDA1610106.zip
#
#           submit_time  day  month  year  hour  minute  second file_extension
# 0 2017-01-03 20:28:52    3      1  2017    20      28      52            zip
# 1 2017-01-03 20:18:21    3      1  2017    20      18      21            zip
# 2 2017-01-03 22:37:08    3      1  2017    22      37       8            zip

# %%
import datetime as dt
print(dt.datetime(2017, 1, 3, 23, 59, 59))
# Out:
# 2017-01-03 23:59:59

# %%
# How many students submitted the assignment after the first deadline (including the students who submitted after
#the second deadline) ?
students_submit_assignment_after_1st_duedate = grades[grades['submit_time'] > dt.datetime(2017, 1, 3, 23, 59, 59)]

# %%
students_submit_assignment_after_1st_duedate
# Out:
#                                                                             submission  \
# 5    https://ckd.upgrad.com/UpGrad/0ab308ab-2b3a-4c74-9bac-c12567a04754/DDA1610059.zip
# 7    https://ckd.upgrad.com/UpGrad/d8969806-6760-4428-a861-545fb4aff136/DDA1610042.zip
# 11    https://ckd.upgrad.com/UpGrad/873211b9-5a3q-4510-91cb-awqbd210a7f/DDA1610008.zip
# 16   https://ckd.upgrad.com/UpGrad/f0c04fba-56d2-4ac5-bcaa-f355a9324c07/DDA1610262.zip
# 21   https://ckd.upgrad.com/UpGrad/7cbc35aa-1d5c-4d17-b669-5bb9ab5b2f3c/DDA1610234.zip
# 24   https://ckd.upgrad.com/UpGrad/a4d13ca3-9b40-4045-a44b-18f15f0b4ab2/DDA1610191.zip
# 28   https://ckd.upgrad.com/UpGrad/3f50884a-4fd0-4826-9838-61a6781939ab/DDA1610160.zip
# 29   https://ckd.upgrad.com/UpGrad/48781790-093d-42c9-9593-5d796ca34fff/DDA1610290.zip
# 30   https://ckd.upgrad.com/UpGrad/cc4f866d-b532-409a-924d-2acbaab74165/DDA1610056.zip
# 36   https://ckd.upgrad.com/UpGrad/9dcaaf78-bcbf-43f1-bfc5-165a993a99b8/DDA1610049.zip
# ...

# %%
students_submit_assignment_after_1st_duedate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44 entries, 5 to 196
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   submission      44 non-null     object
#  1   submit_time     44 non-null     datetime64[ns]
#  2   day             44 non-null     int64
#  3   month           44 non-null     int64
#  4   year            44 non-null     int64
#  5   hour            44 non-null     int64
#  6   minute          44 non-null     int64
#  7   second          44 non-null     int64
#  8   file_extension  44 non-null     object
# dtypes: datetime64[ns](1), int64(6), object(2)
# memory usage: 3.4+ KB

# %%
first_duedate = dt.datetime(2017, 1, 3, 23, 59, 59) 
first_duedate
# Out:
# datetime.datetime(2017, 1, 3, 23, 59, 59)

# %%
grades['submit_time']
# Out:
# 0     2017-01-03 20:28:52
# 1     2017-01-03 20:18:21
# 2     2017-01-03 22:37:08
# 3     2017-01-02 21:43:19
# 4     2017-01-03 15:27:49
#               ...
# 193   2017-01-03 22:43:12
# 194   2017-01-09 23:59:34
# 195   2016-12-19 21:44:13
# 196   2017-01-09 23:23:06
# 197   2017-01-03 22:32:38
# Name: submit_time, Length: 198, dtype: datetime64[ns]

# %%
type(grades['submit_time'])
# Out:
# pandas.core.series.Series

# %%
grades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   submission      198 non-null    object
#  1   submit_time     198 non-null    datetime64[ns]
#  2   day             198 non-null    int64
#  3   month           198 non-null    int64
#  4   year            198 non-null    int64
#  5   hour            198 non-null    int64
#  6   minute          198 non-null    int64
#  7   second          198 non-null    int64
#  8   file_extension  198 non-null    object
# dtypes: datetime64[ns](1), int64(6), object(2)
# memory usage: 14.0+ KB

# %%
grades['submit_time'].dt.date
# Out:
# 0      2017-01-03
# 1      2017-01-03
# 2      2017-01-03
# 3      2017-01-02
# 4      2017-01-03
#           ...
# 193    2017-01-03
# 194    2017-01-09
# 195    2016-12-19
# 196    2017-01-09
# 197    2017-01-03
# Name: submit_time, Length: 198, dtype: object

# %%
first_duedate
# Out:
# datetime.datetime(2017, 1, 3, 23, 59, 59)

# %%
grades['submit_time'].apply(lambda x: type(x))
# Out:
# 0      <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 1      <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 2      <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 3      <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 4      <class 'pandas._libs.tslibs.timestamps.Timestamp'>
#                               ...
# 193    <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 194    <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 195    <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 196    <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 197    <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# Name: submit_time, Length: 198, dtype: object

# %%
grades['is_student_submitted_assignment_after_1st_due_date'] = grades['submit_time'].apply(lambda sub_date: 
                                                                                           True if pd.to_datetime(sub_date)>
                                                                                           first_duedate else False)

# %%
grades['is_student_submitted_assignment_after_1st_due_date']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 193    False
# 194     True
# 195    False
# 196     True
# 197    False
# Name: is_student_submitted_assignment_after_1st_due_date, Length: 198, dtype: bool

# %%
grades['is_student_submitted_assignment_after_1st_due_date'].sum()
# Out:
# 44

# %%
grades
# Out:
#                                                                             submission  \
# 0    https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44aa-88d3-6b36aaa69b02/DDA1610095.zip
# 1    https://ckd.upgrad.com/UpGrad/185242ff-7508-4cc4-afa3-5865733ba1d4/DDA1610288.zip
# 2    https://ckd.upgrad.com/UpGrad/a353d129-c100-4342-aa95-a7018ff93150/DDA1610106.zip
# 3    https://ckd.upgrad.com/UpGrad/002fc912-faa1-4948-9358-fcdabfd7669c/DDA1610261.zip
# 4    https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4ffa-9bf1-06bdb1a7cf8f/DDA1610028.zip
# ..                                                                                 ...
# 193  https://ckd.upgrad.com/UpGrad/ba485323-bba6-4b16-9283-958406a78a6f/DDA1610228.zip
# 194  https://ckd.upgrad.com/UpGrad/a65694d0-339b-44f3-b6bf-a3b15c87ab9c/DDA1610200.zip
# 195  https://ckd.upgrad.com/UpGrad/c3876ddf-2b2f-4a55-952d-2df78fc12ad8/DDA1610183.zip
# 196    https://ckd.upgrad.com/UpGrad/2b9732ad-0985-4af4-a473-4700174afbc0/DDA1610013.R
# ...

# %%
second_duedate = dt.datetime(2017, 1, 9, 23, 59, 59)
second_duedate
# Out:
# datetime.datetime(2017, 1, 9, 23, 59, 59)

# %%
grades['is_student_submitted_assignment_after_2nd_due_date'] = grades['submit_time'].apply(lambda sub_date: 
                                                                                           True if pd.to_datetime(sub_date)
                                                                                           > second_duedate else False)

# %%
grades['is_student_submitted_assignment_after_2nd_due_date'].sum()
# Out:
# 5

# %%
grades['is_student_submitted_assignment_btw_1st_&_2nd_due_date'] = grades['submit_time'].apply(lambda sub_date: 
                                                                                           True if pd.to_datetime(sub_date)
                                                                                           > first_duedate 
                                                                                           and pd.to_datetime(sub_date) 
                                                                                           < second_duedate else False)

# %%
grades['is_student_submitted_assignment_btw_1st_&_2nd_due_date']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 193    False
# 194     True
# 195    False
# 196     True
# 197    False
# Name: is_student_submitted_assignment_btw_1st_&_2nd_due_date, Length: 198, dtype: bool

# %%
grades['is_student_submitted_assignment_btw_1st_&_2nd_due_date'].sum()
# Out:
# 39

# %%
39+44+5
# Out:
# 88

# %%
grades['is_student_submitted_assignment_before_1st_due_date'] = grades['submit_time'].apply(lambda sub_date: 
                                                                                           True if pd.to_datetime(sub_date) 
                                                                                            < first_duedate else False)

# %%
grades['is_student_submitted_assignment_before_1st_due_date'].sum()
# Out:
# 154

# %%
154+39+5
# Out:
# 198

# %%
grades.head(3)
# Out:
#                                                                           submission  \
# 0  https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44aa-88d3-6b36aaa69b02/DDA1610095.zip
# 1  https://ckd.upgrad.com/UpGrad/185242ff-7508-4cc4-afa3-5865733ba1d4/DDA1610288.zip
# 2  https://ckd.upgrad.com/UpGrad/a353d129-c100-4342-aa95-a7018ff93150/DDA1610106.zip
#
#           submit_time  day  month  year  hour  minute  second file_extension  \
# 0 2017-01-03 20:28:52    3      1  2017    20      28      52            zip
# 1 2017-01-03 20:18:21    3      1  2017    20      18      21            zip
# 2 2017-01-03 22:37:08    3      1  2017    22      37       8            zip
#
#    is_student_submitted_assignment_after_1st_due_date  \
# 0                                               False
# 1                                               False
# 2                                               False
#
#    is_student_submitted_assignment_after_2nd_due_date  \
# ...

# %%
grades['date'] = grades['submit_time'].dt.date

# %%
grades['date'].value_counts()
# Out:
# 2017-01-03    120
# 2017-01-09     21
# 2017-01-02     14
# 2017-01-04     12
# 2016-12-30      6
# 2017-01-01      6
# 2017-01-08      3
# 2017-01-10      3
# 2016-12-29      2
# 2016-12-28      2
# 2017-01-07      2
# 2017-01-17      1
# 2017-02-03      1
# 2016-12-21      1
# 2017-01-06      1
# 2016-11-19      1
# 2016-12-31      1
# 2016-12-19      1
# Name: date, dtype: int64

# %%
[date for date in grades['date'].value_counts().index] # pd.to_datetime(date)
# Out:
# [datetime.date(2017, 1, 3),
#  datetime.date(2017, 1, 9),
#  datetime.date(2017, 1, 2),
#  datetime.date(2017, 1, 4),
#  datetime.date(2016, 12, 30),
#  datetime.date(2017, 1, 1),
#  datetime.date(2017, 1, 8),
#  datetime.date(2017, 1, 10),
#  datetime.date(2016, 12, 29),
#  datetime.date(2016, 12, 28),
#  datetime.date(2017, 1, 7),
#  datetime.date(2017, 1, 17),
#  datetime.date(2017, 2, 3),
#  datetime.date(2016, 12, 21),
#  datetime.date(2017, 1, 6),
#  datetime.date(2016, 11, 19),
#  datetime.date(2016, 12, 31),
#  datetime.date(2016, 12, 19)]

# %%
plt.figure(figsize=(12, 5))
_bins = [date for date in grades['date'].value_counts().index]
sns.histplot(x='date', hue='date', data=grades, kde=True)
plt.show()

# %%
plt.figure(figsize=(12, 5))
_bins = [date for date in grades['date'].value_counts().index]
sns.distplot(a=grades['date'], rug=True)
plt.show()
# Out:
# D:\Softwares\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9732\3572079821.py in <module>
#       1 plt.figure(figsize=(12, 5))
#       2 _bins = [date for date in grades['date'].value_counts().index]
# ----> 3 sns.distplot(a=grades['date'], rug=True)
#       4 plt.show()
#
# D:\Softwares\Anaconda\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2634
# ...

# %%
grades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 14 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   submission                                              198 non-null    object
#  1   submit_time                                             198 non-null    datetime64[ns]
#  2   day                                                     198 non-null    int64
#  3   month                                                   198 non-null    int64
#  4   year                                                    198 non-null    int64
#  5   hour                                                    198 non-null    int64
#  6   minute                                                  198 non-null    int64
#  7   second                                                  198 non-null    int64
# ...

# %%
grades['hour'].value_counts()
# Out:
# 23    66
# 21    27
# 22    24
# 20    16
# 0     10
# 1      8
# 14     6
# 18     6
# 13     6
# 15     4
# 17     4
# 12     3
# 10     3
# 3      3
# 19     2
# 4      2
# 16     2
# 2      2
# 6      1
# 8      1
# 11     1
# 9      1
# Name: hour, dtype: int64

# %%
plt.figure(figsize=(12, 5))
sns.histplot(x='hour', hue='hour', data=grades, kde=True)
plt.show()
