# %%
import numpy as np
import pandas as pd

# %%
teacher_df = pd.read_csv("./GOI_data/UDISE_plus-19-20_teachers_howrah_wb.csv")
teacher_df
# Out:
#      Academic_Year  State_Code   State_Name  District_Code District_Name  \
# 0          2019-20          19  West Bengal           1916        HOWRAH
# 1          2019-20          19  West Bengal           1916        HOWRAH
# 2          2019-20          19  West Bengal           1916        HOWRAH
# 3          2019-20          19  West Bengal           1916        HOWRAH
# 4          2019-20          19  West Bengal           1916        HOWRAH
# ...            ...         ...          ...            ...           ...
# 1640       2019-20          19  West Bengal           1916        HOWRAH
# 1641       2019-20          19  West Bengal           1916        HOWRAH
# 1642       2019-20          19  West Bengal           1916        HOWRAH
# 1643       2019-20          19  West Bengal           1916        HOWRAH
# 1644       2019-20          19  West Bengal           1916        HOWRAH
#
#       Block_Code                    Block_Name  School_Management_Id  \
# ...

# %%
teacher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1645 entries, 0 to 1644
# Data columns (total 36 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Academic_Year                         1645 non-null   object
#  1   State_Code                            1645 non-null   int64
#  2   State_Name                            1645 non-null   object
#  3   District_Code                         1645 non-null   int64
#  4   District_Name                         1645 non-null   object
#  5   Block_Code                            1645 non-null   int64
#  6   Block_Name                            1645 non-null   object
#  7   School_Management_Id                  1645 non-null   int64
#  8   School_Management_Name                1645 non-null   object
#  9   School_Category_Id                    1645 non-null   int64
#  10  School_Category_Name                  1645 non-null   object
# ...

# %%
teacher_df.isnull().sum()
# Out:
# Academic_Year                           0
# State_Code                              0
# State_Name                              0
# District_Code                           0
# District_Name                           0
# Block_Code                              0
# Block_Name                              0
# School_Management_Id                    0
# School_Management_Name                  0
# School_Category_Id                      0
# School_Category_Name                    0
# Academic_Qualification_Id               0
# Academic_Qualification_Name             0
# Professional_Qualification_Id           0
# Professional_Qualification_Name         0
# Only_Pre_Primary_Male                   0
# Only_Pre_Primary_Female                 0
# Pre_Primary_and_Primary_Male            0
# Pre_Primary_and_Primary_Female          0
# Only_Primary_Male                       0
# Only_Primary_Female                     0
# Primary_and_Upperprimary_Male           0
# ...

# %%
teacher_df.isnull().sum(axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1640    0
# 1641    0
# 1642    0
# 1643    0
# 1644    0
# Length: 1645, dtype: int64

# %%
teacher_df.describe()
# Out:
#        State_Code  District_Code     Block_Code  School_Management_Id  \
# count      1645.0         1645.0    1645.000000           1645.000000
# mean         19.0         1916.0  191610.217629             13.306991
# std           0.0            0.0       4.878704             23.527744
# min          19.0         1916.0  191601.000000              1.000000
# 25%          19.0         1916.0  191606.000000              1.000000
# 50%          19.0         1916.0  191611.000000              5.000000
# 75%          19.0         1916.0  191615.000000             15.000000
# max          19.0         1916.0  191617.000000             98.000000
#
#        School_Category_Id  Academic_Qualification_Id  \
# count         1645.000000                1645.000000
# mean             2.974468                   3.933131
# std              2.171891                   1.236766
# min              1.000000                   1.000000
# 25%              1.000000                   3.000000
# ...

# %%
teacher_df.columns
# Out:
# Index(['Academic_Year', 'State_Code', 'State_Name', 'District_Code',
#        'District_Name', 'Block_Code', 'Block_Name', 'School_Management_Id',
#        'School_Management_Name', 'School_Category_Id', 'School_Category_Name',
#        'Academic_Qualification_Id', 'Academic_Qualification_Name',
#        'Professional_Qualification_Id', 'Professional_Qualification_Name',
#        'Only_Pre_Primary_Male', 'Only_Pre_Primary_Female',
#        'Pre_Primary_and_Primary_Male', 'Pre_Primary_and_Primary_Female',
#        'Only_Primary_Male', 'Only_Primary_Female',
#        'Primary_and_Upperprimary_Male', 'Primary_and_Upperprimary_Female',
#        'Only_Upperprimary_Male', 'Only_Upperprimary_Female',
#        'Upperprimary_and_Secondary_Male', 'Upperprimary_and_Secondary_Female',
#        'Only_Secondary_Male', 'Only_Secondary_Female',
#        'Secondary_and_Highersecondary_Male',
#        'Secondary_and_Highersecondary_Female', 'Only_Highersecondary_Male',
# ...

# %%
teacher_df
# Out:
#      Academic_Year  State_Code   State_Name  District_Code District_Name  \
# 0          2019-20          19  West Bengal           1916        HOWRAH
# 1          2019-20          19  West Bengal           1916        HOWRAH
# 2          2019-20          19  West Bengal           1916        HOWRAH
# 3          2019-20          19  West Bengal           1916        HOWRAH
# 4          2019-20          19  West Bengal           1916        HOWRAH
# ...            ...         ...          ...            ...           ...
# 1640       2019-20          19  West Bengal           1916        HOWRAH
# 1641       2019-20          19  West Bengal           1916        HOWRAH
# 1642       2019-20          19  West Bengal           1916        HOWRAH
# 1643       2019-20          19  West Bengal           1916        HOWRAH
# 1644       2019-20          19  West Bengal           1916        HOWRAH
#
#       Block_Code                    Block_Name  School_Management_Id  \
# ...

# %%
teacher_df.groupby(by='Block_Name').mean()
# Out:
#                               State_Code  District_Code  Block_Code  \
# Block_Name
# AMTA-I                              19.0         1916.0    191601.0
# AMTA-II                             19.0         1916.0    191602.0
# BAGNAN-I                            19.0         1916.0    191603.0
# BAGNAN-II                           19.0         1916.0    191604.0
# BALLY MUNICIPALITY                  19.0         1916.0    191616.0
# BALLY- JAGACHA                      19.0         1916.0    191605.0
# DOMJUR                              19.0         1916.0    191614.0
# HOWRAH MUNICIPAL CORPORATION        19.0         1916.0    191615.0
# JAGATBALLAVPUR                      19.0         1916.0    191609.0
# PANCHLA                             19.0         1916.0    191612.0
# SANKRAIL                            19.0         1916.0    191613.0
# SHYAMPUR-I                          19.0         1916.0    191610.0
# SHYAMPUR-II                         19.0         1916.0    191611.0
# ...

# %%
columns = ['School_Management_Id', 'Secondary_and_Highersecondary_Female', 'Only_Highersecondary_Female',
           'Only_Secondary_Female']
teacher_df['2ndry_and_Higher2ndry_Female'] = teacher_df['Only_Secondary_Female'] + teacher_df['Only_Highersecondary_Female']

# %%
teacher_df.pivot_table(index=['District_Name', 'Block_Name'], values=columns,  aggfunc='sum', sort=False)
# Out:
#                                             Only_Highersecondary_Female  \
# District_Name Block_Name
# HOWRAH        BAGNAN-II                                              15
#               ULUBERIA-II                                            17
#               JAGATBALLAVPUR                                         22
#               SHYAMPUR-II                                            16
#               PANCHLA                                                27
#               DOMJUR                                                 34
#               HOWRAH MUNICIPAL CORPORATION                          143
#               ULUBERIA MUNICIPALITY                                  15
#               ULUBERIA-I                                             16
#               AMTA-I                                                  9
#               AMTA-II                                                22
#               BAGNAN-I                                               19
# ...
